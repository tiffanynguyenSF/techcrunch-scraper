# %% [markdown]
# <a href="https://colab.research.google.com/github/cpatiffanynguyen/techcrunch-scraper/blob/main/BeautifulSoup_AI_Venture_Startup_articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from google.colab import files

# %%
def scrape_articles_info(urls, pages=1):
    articles_info = []
    for base_url in urls:
        for page in range(1, pages + 1):
            url = f"{base_url}page/{page}/"
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.content, 'html.parser')
                articles = soup.find_all('div', class_='post-block post-block--image post-block--unread')
                for article in articles:
                    title = article.find('a', class_='post-block__title__link').get_text(strip=True)
                    date = article.find('time')['datetime'][:10]
                    article_url = article.find('a', class_='post-block__title__link')['href']
                    articles_info.append({'Title': title, 'Date': date, 'URL': article_url})
            else:
                print(f"Failed to retrieve webpage: {url}")
    return articles_info

# %%
urls_to_scrape = [
    'https://techcrunch.com/category/startups/',
    'https://techcrunch.com/category/venture/',
    'https://techcrunch.com/category/artificial-intelligence/',
]

# %%
articles_info = scrape_articles_info(urls_to_scrape)
articles_df = pd.DataFrame(articles_info, columns=['Title', 'Date', 'URL'])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
display(articles_df)
# Out:
#                                                                                                     Title  \
# 0                                             Modal raises $25M to train corporate workers on data and AI
# 1                                           Quadratic is reimagining the spreadsheet with a focus on data
# 2                      Hailo lands $120 million to keep battling Nvidia as most AI chip startups struggle
# 3                        Seso is building software to fix farm workforces and solve agriculture’s HR woes
# 4                        TechCrunch Early Stage 2024 Women’s Breakfast: Exploring AI’s impact on founders
# 5                                 Autism Impact Fund closes $60 million first fund and broadens its scope
# 6     Animal-free egg protein startup Onego Bio is one step closer to cracking the traditional egg market
# 7                                 Footage from 2020 shows Astra rocket exploding during prelaunch testing
# 8                         Why Trump’s digital media company is different from other money-losing startups
# 9                               Learn startup best practices with Fidelity and others at Early Stage 2024
# 10        Terraform Industries converts electricity and air into synthetic natural gas for the first time
# 11                             Ads on Discord, AT&T passcode resets and podcast changes for Android users
# 12               Robinhood’s new Gold Card, BaaS challenges and the tiny startup that caught Stripe’s eye
# 13             MIT tool shows climate change could cost Texans a month and a half of outdoor time by 2080
# 14                              Deal Dive: Iron Sheepdog is fixing short-haul trucking from the bottom up
# 15                                                  Startups Weekly: Big shake-ups at the AI heavyweights
# 16          Nine crypto VCs on why Q1 investments were so hot and how it compares to previous bull market
# 17                                              Pitch Deck Teardown: Plantee Innovations’ $1.4M seed deck
# 18                                       Databricks’ GPT rival and who’s investing in ‘underdog’ founders
# 19                                             How a tiny 4-person startup, Supaglue, caught Stripe’s eye
# 20                       Seso is building software to fix farm workforces and solve agriculture’s HR woes
# 21                                Autism Impact Fund closes $60 million first fund and broadens its scope
# 22    Animal-free egg protein startup Onego Bio is one step closer to cracking the traditional egg market
# 23      Sam Altman gives up control of OpenAI Startup Fund, resolving unusual corporate venture structure
# 24                        Why Trump’s digital media company is different from other money-losing startups
# 25                                              TechCrunch Minute: Amazon bets $4B on Anthropic’s success
# 26                             Ads on Discord, AT&T passcode resets and podcast changes for Android users
# 27                                       GGV Capital is no more, as partners announce two separate brands
# 28               Robinhood’s new Gold Card, BaaS challenges and the tiny startup that caught Stripe’s eye
# 29                              Deal Dive: Iron Sheepdog is fixing short-haul trucking from the bottom up
# 30          Nine crypto VCs on why Q1 investments were so hot and how it compares to previous bull market
# 31                                       Databricks’ GPT rival and who’s investing in ‘underdog’ founders
# 32                        Meet Kidsy, a kids’ clothing startup that sells what parents need at a discount
# 33                                  Skyflow raises $30M more as AI spikes demand for its privacy business
# 34                               Ibotta’s expansion into enterprise should set it up for a successful IPO
# 35                                                     Why a16z-backed Wonderschool is acquiring EarlyDay
# 36                               Matter Venture Partners raises $300M first fund to invest in ‘hard tech’
# 37          Boutique startup studio super{set} gets another $90 million to co-found data and AI companies
# 38       Furnished rental startup Blueground defies proptech woes with $560M in revenue, a new $45M raise
# 39          Climate tech VC Satgana closes first fund that targets early-stage startups in Africa, Europe
# 40                     Hailo lands $120 million to keep battling Nvidia as most AI chip startups struggle
# 41                       TechCrunch Early Stage 2024 Women’s Breakfast: Exploring AI’s impact on founders
# 42                                    Beyoncé’s new album ‘Cowboy Carter’ is a statement against AI music
# 43      Sam Altman gives up control of OpenAI Startup Fund, resolving unusual corporate venture structure
# 44                                            ChatGPT no longer requires an account — but there’s a catch
# 45                                              TechCrunch Minute: Amazon bets $4B on Anthropic’s success
# 46                             Women in AI: Urvashi Aneja is researching the social impact of AI in India
# 47  Women in AI: Brandie Nonnecke of UC Berkeley says investors should insist on responsible AI practices
# 48                              Women in AI: Kate Devlin of King’s College is researching AI and intimacy
# 49                                           This Week in AI: Let us not forget the humble data annotator
# 50                                                  Startups Weekly: Big shake-ups at the AI heavyweights
# 51        Google DeepMind CEO Demis Hassabis gets UK knighthood for ‘services to artificial intelligence’
# 52                                           OpenAI built a voice cloning tool, but you can’t use it… yet
# 53             The AI world needs more data transparency and web3 startup Space and Time says it can help
# 54                                       Databricks’ GPT rival and who’s investing in ‘underdog’ founders
# 55                                                 What is Elon Musk’s Grok chatbot and how does it work?
# 56                                             X’s Grok chatbot will soon get an upgraded model, Grok-1.5
# 57                       Uber Eats courier’s fight against AI bias shows justice under UK law is hard won
# 58                                  Skyflow raises $30M more as AI spikes demand for its privacy business
# 59                                             Google.org launches $20M generative AI accelerator program
#
#           Date  \
# 0   2024-04-02
# 1   2024-04-02
# 2   2024-04-02
# 3   2024-04-02
# 4   2024-04-02
# 5   2024-04-02
# 6   2024-04-01
# 7   2024-04-01
# 8   2024-04-01
# 9   2024-04-01
# 10  2024-04-01
# 11  2024-04-01
# 12  2024-03-31
# 13  2024-03-30
# 14  2024-03-30
# 15  2024-03-29
# 16  2024-03-29
# 17  2024-03-29
# 18  2024-03-29
# 19  2024-03-29
# 20  2024-04-02
# 21  2024-04-02
# 22  2024-04-01
# 23  2024-04-01
# 24  2024-04-01
# 25  2024-04-01
# 26  2024-04-01
# 27  2024-03-31
# 28  2024-03-31
# 29  2024-03-30
# 30  2024-03-29
# 31  2024-03-29
# 32  2024-03-28
# 33  2024-03-28
# 34  2024-03-28
# 35  2024-03-28
# 36  2024-03-28
# 37  2024-03-28
# 38  2024-03-28
# 39  2024-03-28
# 40  2024-04-02
# 41  2024-04-02
# 42  2024-04-01
# 43  2024-04-01
# 44  2024-04-01
# 45  2024-04-01
# 46  2024-04-01
# 47  2024-03-31
# 48  2024-03-30
# 49  2024-03-30
# 50  2024-03-29
# 51  2024-03-29
# 52  2024-03-29
# 53  2024-03-29
# 54  2024-03-29
# 55  2024-03-29
# 56  2024-03-28
# 57  2024-03-28
# 58  2024-03-28
# 59  2024-03-28
#
#                                                                                                                                               URL
# 31                                                https://techcrunch.com/2024/03/29/databricks-gpt-rival-and-whos-investing-in-underdog-founders/
# 32                   https://techcrunch.com/2024/03/28/kidsy-is-a-startup-selling-liquidated-childrens-clothing-and-gear-like-a-tj-maxx-for-kids/
# 33                                                               https://techcrunch.com/2024/03/28/skyflow-raises-30m-ai-spikes-privacy-business/
# 34                                     https://techcrunch.com/2024/03/28/ibottas-expansion-into-enterprise-should-set-it-up-for-a-successful-ipo/
# 35                                                          https://techcrunch.com/2024/03/28/why-a16z-backed-wonderschool-is-acquiring-earlyday/
# 36                                                                 https://techcrunch.com/2024/03/28/wen-hsieh-matter-venture-partners-300m-fund/
# 37                                                                           https://techcrunch.com/2024/03/28/superset-startup-studio-fundraise/
# 38                                                                      https://techcrunch.com/2024/03/28/furnished-rental-blueground-raises-45m/
# 39                                                                                   https://techcrunch.com/2024/03/28/satgana-closes-first-fund/
# 40                                                           https://techcrunch.com/2024/04/02/hailo-ai-chip-startup-lands-120m-to-battle-nvidia/
# 41                               https://techcrunch.com/2024/04/02/techcrunch-early-stage-2024-womens-breakfast-exploring-ais-impact-on-founders/
# 42                                                       https://techcrunch.com/2024/04/01/beyonce-cowboy-carter-is-a-statement-against-ai-music/
# 43            https://techcrunch.com/2024/04/01/sam-altman-gives-up-control-of-openai-startup-fund-resolving-unusual-corporate-venture-structure/
# 44                                                    https://techcrunch.com/2024/04/01/chatgpt-no-longer-requires-an-account-but-theres-a-catch/
# 45                                                      https://techcrunch.com/2024/04/01/techcrunch-minute-amazon-bets-4b-in-anthropics-success/
# 46                                   https://techcrunch.com/2024/04/01/women-in-ai-urvashi-aneja-is-researching-the-social-impact-of-ai-in-india/
# 47        https://techcrunch.com/2024/03/31/women-in-ai-brandie-nonnecke-of-uc-berkeley-says-investors-should-insist-on-responsible-ai-practices/
# 48                                     https://techcrunch.com/2024/03/30/women-in-ai-kate-devlin-of-kings-college-is-researching-ai-and-intimacy/
# 49                                                 https://techcrunch.com/2024/03/30/this-week-in-ai-let-us-not-forget-the-humble-data-annotator/
# 50                                                                                 https://techcrunch.com/2024/03/29/startups-weekly-ai-shakeups/
# 51               https://techcrunch.com/2024/03/29/google-deepmind-ceo-demis-hassabis-gets-uk-knighthood-for-services-to-artificial-intelligence/
# 52                                                                          https://techcrunch.com/2024/03/29/openai-custom-voice-engine-preview/
# 53                  https://techcrunch.com/2024/03/29/the-ai-world-needs-more-data-transparency-and-web3-startup-space-and-time-says-it-can-help/
# 54                                                https://techcrunch.com/2024/03/29/databricks-gpt-rival-and-whos-investing-in-underdog-founders/
# 55                                                        https://techcrunch.com/2024/03/29/what-is-elon-musks-grok-chatbot-and-how-does-it-work/
# 56                                                    https://techcrunch.com/2024/03/28/xs-grok-chatbot-will-soon-get-an-upgraded-model-grok-1-5/
# 57                                                                                https://techcrunch.com/2024/03/28/uber-eats-ai-bias-settlement/
# 58                                                               https://techcrunch.com/2024/03/28/skyflow-raises-30m-ai-spikes-privacy-business/
# 59                                                   https://techcrunch.com/2024/03/28/google-org-launches-20m-generative-ai-accelerator-program/

# %%
articles_df = pd.DataFrame(articles_df, columns=['Title', 'URL', 'Date'])
articles_df.to_excel('latest_techcrunch.xlsx', index=False, engine='openpyxl')

# %%
from google.colab import files
files.download('/content/latest_techcrunch.xlsx')
